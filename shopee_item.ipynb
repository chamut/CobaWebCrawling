# %%
import pandas as pd
item = pd.DataFrame(columns = ['name', 'rating_star', 'price', 'price_before_discount', 'description'])
item
# Out:
# Empty DataFrame
# Columns: [name, rating_star, price, price_before_discount, description]
# Index: []

# %%
import requests
header = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'}
url = "https://shopee.co.id/api/v2/item/get?itemid=4762406258&shopid=65323877"
response = requests.get(url, headers=header)
response.json()
# Out:
# {'item': {'itemid': 4762406258,
#   'price_max_before_discount': 3520000000,
#   'item_status': 'normal',
#   'can_use_wholesale': False,
#   'show_free_shipping': False,
#   'estimated_days': 2,
#   'is_hot_sales': None,
#   'is_slash_price_item': False,
#   'upcoming_flash_sale': None,
#   'slash_lowest_price': None,
#   'is_partial_fulfilled': False,
#   'condition': 0,
#   'add_on_deal_info': None,
#   'is_non_cc_installment_payment_eligible': False,
#   'categories': [{'display_name': 'Makanan & Minuman',
#     'catid': 157,
#     'image': None,
#     'no_sub': False,
#     'is_default_subcat': False,
#     'block_buyer_platform': None},
#    {'display_name': 'Makanan Instan',
#     'catid': 12561,
#     'image': None,
#     'no_sub': False,
#     'is_default_subcat': False,
#     'block_buyer_platform': None},
#    {'display_name': 'Mie & Pasta Instan',
#     'catid': 12563,
#     'image': None,
#     'no_sub': True,
#     'is_default_subcat': False,
# ...

# %% [markdown]
# soup = BeautifulSoup(response.text, 'lxml')
# soup.select('a')
# #nama, rating, harga, deskripsi
# for a in soup.select('a'):
#     print(a.get('href'))

# %%
name = response.json()['item']['name']
rating_star = response.json()['item']['item_rating']['rating_star']
price = response.json()['item']['price']/100000
price_before_discount = response.json()['item']['price_before_discount']/100000
description = response.json()['item']['description']

# %%
item = item.append({'name': name, 'rating_star': rating_star, 'price': price, 'price_before_discount': price_before_discount, 'description': description}, ignore_index=True)

# %%
item
# Out:
#                                                 name  rating_star    price  \
# 0  Best Wok Mi Goreng Original Multipack 425 gr +...          5.0  29500.0
#
#    price_before_discount                                        description
# 0                35200.0  Paket ini berisi 1x Best Wok Mi Goreng Origina...

# %% [markdown]
# links = [
#     'https://shopee.co.id/api/v2/item/get?itemid=4645446329&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=6245448746&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=6145448760&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=5439512841&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=5539511374&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=6839539160&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=7739506384&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=5639511384&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=5739511304&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=5639511373&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=5639511373&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=1226374049&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=1236983089&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=1226373746&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=1226373748&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=1226373752&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=7200405281&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=7545444393&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=7945444349&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=7450628531&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=6345448797&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=5350626127&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=4545450863&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=1803099757&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=5115994877&shopid=221187100',
#     'https://shopee.co.id/api/v2/item/get?itemid=3516075634&shopid=221187100',
#     'https://shopee.co.id/api/v2/item/get?itemid=6246215661&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=1966543199&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=1921167011&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=3159605623&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=6038583597&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=7065821059&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=4465812441&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=3965389825&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=5157891187&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=4665379805&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=3465473508&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=7465820135&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=8600395620&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=5065822019&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=4657905187&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=6165378884&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid
shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=5958741537&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=1921168714&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=1921167142&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=2854405025&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=2854405058&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=6843214589&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=1179856169&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=2334368192&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=2091926232&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=1179856134&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=1408491855&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=6218677613&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=7943219174&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=5437350111&shopid=65323877',
#     'https://shopee.co.id/api/v2/item/get?itemid=7531846048&shopid=22674495',
#     'https://shopee.co.id/api/v2/item/get?itemid=2699028770&shopid=22674495'
# ]

# %% [markdown]
# links = [
#     'https://shopee.co.id/api/v2/item/get?itemid=3716078266&shopid=22674495',
#     'https://shopee.co.id/api/v2/item/get?itemid=3716078266&shopid=22674495',
#     'https://shopee.co.id/api/v2/item/get?itemid=2713488678&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=7932480982&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=3771453714&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=5217417179&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=2873252103&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=2523893532&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=5138367969&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=3254630870&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=7271157328&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=2278245911&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=4421444297&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=5805433332&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=2270070289&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=6214357723&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=4905755752&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=5514342447&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=6854500127&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=3454555950&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=6434557394&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=3834654140&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=4635381931&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=5132601388&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=4533782934&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=6334681525&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=6126421134&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=7805762725&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=1888794578&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=3254901471&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=5754721396&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=5834713330&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=3254630870&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=4743949869&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=6654744476&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=5754487415&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=6647436459&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=2548167792&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=2824224537&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=6337699888&shopid=40847197',
#     'https://shopee.co.id/api/v2/item/get?itemid=3734812622&shopid=40847197'
# ]

# %%
links = [
    'https://shopee.co.id/api/v2/item/get?itemid=6634715271&shopid=40847197',
    
]

# %%
for link in links:
    header = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'}
    url = link
    response = requests.get(url, headers=header)
    #ngambil nilai yang diinginkan
    name = response.json()['item']['name']
    rating_star = response.json()['item']['item_rating']['rating_star']
    price = response.json()['item']['price']/100000
    price_before_discount = response.json()['item']['price_before_discount']/100000
    description = response.json()['item']['description']
    #masukin ke dataframe
    item = item.append({'name': name, 'rating_star': rating_star, 'price': price, 'price_before_discount': price_before_discount, 'description': description}, ignore_index=True)

# %%
item
# Out:
#                                                   name  rating_star    price  \
# 0    Best Wok Mi Goreng Original Multipack 425 gr +...     5.000000  29500.0
# 1                                  Indomie Goreng 85gr     4.916466   2900.0
# 2                        Tawon Minyak Goreng Refill 2L     4.926207  26300.0
# 3                     Gulaku Pillow Pack Premium 200gr     4.895470   3600.0
# 4    DayMan Razor Twin Blade (With Lubricant/Pelici...     4.964286   8500.0
# ..                                                 ...          ...      ...
# 199  Miniso official Marvel cartoon series crisper ...     5.000000  38935.0
# 200  Miniso Official Marvel Kotak makanan Bento Box...     4.777429  42415.0
# 201  Miniso Official Marvel Cutlery Set Garpu dan s...     4.894977  50915.0
# 202  MINISO Fruit Series Cutlery / Set Sendok Garpu...     4.917355  42415.0
# 203  MINISO Pantone CutlerySet Alat Makan Sendok + ...     4.705882  47405.0
#
# ...

# %%
item.to_csv(r'D:\PKL\itemShopee.csv')
